# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg" alt="Fasilkom UI" width="300"/>
#
# CSGE603130 • Kecerdasan Artifisial dan Sains Data Dasar
#
# Semester Genap 2024/2025
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ##**Lab 2: *Statistics, Matplotlib and Seaborn***
#
# ###**Tenggat Waktu: 16 Februari 2025, 23.55 WIB**
# </center>
#
# ### **Ketentuan:**
#
# 1. Dokumen template lab dengan format .ipynb dan dataset (jika dibutuhkan) telah disediakan di SCeLe
# 2. Jalankan kode pada dokumen .ipynb dan perhatikan dengan saksama apa yang potongan kode tersebut lakukan beserta dengan keluarannya. Jawablah **pertanyaan** yang disisipkan pada potongan program yang diberikan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **Kelas_LabX_NPM_Nama.ipynb** . Contoh: A_Lab2_1806205773_Abdurrafi Arief.ipynb. Kesalahan dalam pengumpulan nama akan dikenakan pinalti sebesar 5 poin.
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLe sesuai dengan kelas masing-masing sebelum **Tenggat Waktu: 16 Februari 2025, 23.55 WIB**.
# 5. Keterlambatan pengumpulan akan dikenakan pinalti sebesar 5 poin per jam (pembulatan ke atas). Dengan cut off 1 hari.
# 6. Lab ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin maupun mengambil jawaban orang lain) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.
# 7. Pakta Integritas **Wajib** di isi dan di jalankan. Submisi hanya akan dinilai jika pakta integritas di isi dan di jalankan.
# 8. Sebelum di kumpulkan, kode **WAJIB** dijalankan. Jika tidak, dikenakan penalti sebesar 50%.
# 9. Mahasiswa wajib mencantumkan semua sumber yang menjadi referensi jawaban, termasuk GPT.

# %%
# Isi dengan data diri Anda
NAMA = "Scudetto Ciano Syam"
KELAS = "C"
NPM = "2206083294"
USERNAME_KAGGLE = "scudetto"

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = ['https://accounting.binus.ac.id/2020/12/19/mengenal-box-plot-box-and-whisker-plots/, https://drive.google.com/drive/folders/19SnfT6yl-X33y05ZnnUPSckdzA6wfOgp?usp=sharing,https://stackoverflow.com/questions/6705581/rotating-xticks-causes-the-ticks-to-be-partially-hidden, chat gpt ' ]

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dari kelas %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)" % (NAMA, KELAS, NPM, NAMA)

print(PERNYATAAN_INTEGRITAS)
# Out:
# Saya, Scudetto Ciano Syam dari kelas C dengan NPM 2206083294, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.
# Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.
#
# Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.
#    (Scudetto Ciano Syam)

# %% [markdown]
# # Exploratory Data Analysis
#
# **Exploratory Data Analysis (EDA)** adalah proses untuk mengeksplorasi dan memahami pola serta karakteristik utama dari suatu dataset. EDA merupakan tahap awal yang krusial dalam analisis data karena hasil dari EDA dapat mempengaruhi keputusan terkait data processing, data modeling, dan langkah-langkah analitis selanjutnya.
#
# Proses EDA melibatkan dua komponen utama: **statistik deskriptif** dan **visualisasi data**. Melalui statistik deskriptif, kita menghitung metrik seperti mean, median, mode, dan standar deviasi untuk memahami distribusi dan variasi data. Sedangkan, melalui visualisasi data, kita dapat melihat pola dan tren dalam data menggunakan grafik seperti histogram, box plot, dan scatter plot. EDA juga dapat dibagi menjadi beberapa jenis analisis seperti **Univariate Analysis**, **Bivariate Analysis**, dan **Multivariate Analysis**.
#
# EDA membantu kita mengidentifikasi masalah potensial dan mengarahkan analisis lebih lanjut untuk mendapatkan wawasan berharga dari data.

# %% [markdown]
# ## Deskripsi Dataset `supermarket_sales.csv`
#
# Dalam EDA kali ini, kita akan menganalisis dataset `supermarket_sales.csv` untuk memahami keterhubungan antar ciri-ciri transaksi-transaksi yang dilakukan pada 3 supermarket berbeda. Analisis ini akan melibatkan pemeriksaan statistik deskriptif, visualisasi data, serta analisis hubungan antara berbagai fitur untuk mengidentifikasi pola-pola yang signifikan. Contoh beberapa analisis yang menarik adalah "product line apa yang paling populer di masing-masing supermarket?", "metode pembayaran apa yang paling sering/jarang digunakan oleh pelanggan yang merupakan seorang member?", dan hal-hal menarik lainnya. Dataset ini mencakup berbagai informasi transaksi, yaitu:
# - `Invoice id`: Computer generated sales slip invoice identification number
# - `Branch`: Branch of supercenter (3 branches are available identified by A, B and C).
# - `City`: Location of supercenters
# - `Customer type`: Type of customers, recorded by Members for customers using member card and Normal for without member card.
# - `Gender`: Gender type of customer
# - `Product line`: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - `Unit price`: Price of each product in $
# - `Quantity`: Number of products purchased by customer
# - `Tax 5%`: tax fee for customer buying
# - `Total`: Total price including tax
# - `Date`: Date of purchase (Record available from January 2019 to March 2019)
# - `Time`: Purchase time (10am to 9pm)
# - `Payment`: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
# - `cogs`: Cost of goods sold (before tax)
# - `gross margin percentage`: Gross margin percentage
# - `gross income`: Gross income
# - `Rating`: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)
#
# Sumber dataset: https://www.kaggle.com/datasets/aungpyaeap/supermarket-sales

# %%
# Import semua library yang dibutuhkan
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as scp

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df = pd.read_csv("supermarket_sales.csv")

# %%
# Melihat ukuran data
total_rows, total_features = df.shape
print("Jumlah data: ", total_rows)
print("Jumlah fitur: ", total_features)
# Out:
# Jumlah data:  1000
# Jumlah fitur:  17

# %%
# Melihat cuplikan beberapa baris pertama dataset
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# Di Pandas, terdapat metode `.info()` yang berguna untuk mendapatkan ringkasan informasi dari DataFrame, seperti nama-nama fitur, jumlah data yang tidak null (non-null), dan tipe data untuk setiap fitur. Penggunaan metode ini membantu kita dengan cepat memahami struktur DataFrame yang sedang kita kerjakan.

# %%
# Melihat informasi nama fitur, banyaknya nilai non-null, dan tipe dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# Melihat proporsi missing values pada setiap fitur
missing_values_info = []
for col in df:
    missing = df[col].isna().sum()
    missing_values_info.append([col, missing, (missing/len(df))*100])

index_output = list(range(0, len(missing_values_info)))
pd.DataFrame(missing_values_info, columns=['Fitur', '# Missing','% Missing'], index=index_output).sort_values(by=['% Missing'], ascending=False, ignore_index=True)
# Out:
#                       Fitur  # Missing  % Missing
# 0                Invoice ID          0        0.0
# 1                     Total          0        0.0
# 2              gross income          0        0.0
# 3   gross margin percentage          0        0.0
# 4                      cogs          0        0.0
# 5                   Payment          0        0.0
# 6                      Time          0        0.0
# 7                      Date          0        0.0
# 8                    Tax 5%          0        0.0
# 9                    Branch          0        0.0
# 10                 Quantity          0        0.0
# 11               Unit price          0        0.0
# 12             Product line          0        0.0
# 13                   Gender          0        0.0
# 14            Customer type          0        0.0
# 15                     City          0        0.0
# 16                   Rating          0        0.0

# %% [markdown]
# Pada dataset ini, tidak ada missing values sehingga kita bisa lanjut ke tahap selanjutnya. Untuk tahap pre-processing data akan Anda pelajari lebih lanjut pada Lab selanjutnya :D.

# %%
# Melihat descriptive statistics dari fitur-fitur numerik pada dataset,
# yaitu jumlah, rata-rata, standar deviasi, nilai minimum, kuartil 1-3, dan nilai maksimum dari setiap fitur
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
# Melihat ringkasan statistics untuk fitur-fitur bertipe 'object' (kategorikal atau string) pada dataset,
# yaitu jumlah, jumlah nilai unik, nilai paling sering muncul (modus), dan frekuensi modus
df.describe(include='object')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#             Date   Time  Payment
# count       1000   1000     1000
# unique        89    506        3
# top     2/7/2019  19:48  Ewallet
# freq          20      7      345

# %% [markdown]
# ## Descriptive Statistics
# Terdapat berbagai pengukuran yang dapat diterapkan untuk statistik deskriptif. Pengukuran ini sudah pernah Anda pelajari pada kuliah Statistika dan Probabilitas:
# 1. *Central tendency* (mean, median, mode)
# 2. *Variability* atau *dispersion* (variance, standard deviation)
# 3. Minimum, maximum
# 4. Range
# 5. Quartile
# 6. Percentile
#
# **Central tendency data dapat digunakan untuk memahami distribusi data.** `Mean` biasanya lebih tepat digunakan untuk data dengan distribusi normal (di mana data tersebar secara simetris di sekitar pusat). Di sisi lain, `median` lebih sesuai untuk distribusi yang miring (*skewed*), di mana data condong ke satu sisi. Untuk data kategorikal, hanya `mode` yang dapat digunakan.
#
# Namun, *central tendency* saja tidak cukup untuk menggambarkan distribusi data secara keseluruhan, karena tidak memberikan informasi mengenai tingkat penyebaran data. **Measure of variability** adalah alat ukur yang digunakan untuk memahami **variasi atau seberapa luas data tersebar**. Beberapa cara untuk mengukur variability data termasuk menggunakan `range` (jangkauan) dan `standard deviation` (simpangan baku).
#
# Berikut adalah penggunaan statistik deskriptif (1), (2), (3) dari fitur `gross income` yang menyatakan pendapatan kotor dari suatu transaksi:

# %%
gross_income = df["gross income"]
stats = [
    ['Mean', np.mean(gross_income)],
    ['Median', np.median(gross_income)],
    ['Mode', scp.mode(gross_income)[0]],
    ['Variance', np.var(gross_income)],
    ['Standard Deviation', np.std(gross_income)],
    ['Minimum', np.min(gross_income)],
    ['Maximum', np.max(gross_income)],
]
pd.DataFrame(stats, columns=['Measure', 'Value'])
# Out:
#               Measure       Value
# 0                Mean   15.379369
# 1              Median   12.088000
# 2                Mode    4.154000
# 3            Variance  136.959498
# 4  Standard Deviation   11.702970
# 5             Minimum    0.508500
# 6             Maximum   49.650000

# %% [markdown]
# Pada hasil di atas, bisa kita lihat bahwa measurement central tendency terbesar dimiliki oleh **mean** dengan urutan mean > median > mode.
#
# Data tersebar sebesar 11.702970 dari nilai mean, menunjukkan bahwa ada variasi yang signifikan dalam data. Nilai maksimum adalah 49.650000 dan nilai minimum adalah 0.508500. Ini menunjukkan bahwa data cenderung tersebar di berbagai rentang nilai dengan nilai yang lebih kecil cenderung lebih banyak karena posisi median yang jauh lebih dekat dengan nilai minimum dibandingkan dengan nilai maximum. Dengan kata lain, kemungkinan data ini padat di nilai yang rendah atau padat di kiri, mengindikasikan distribusi data **skewed to the right** atau **positively skewed**.

# %% [markdown]
# Untuk membuktikan pertanyaan di atas, kita akan coba visualisasikan fitur `gross income` dengan Kernel Density Estimation (KDE) plot karena dapat memberikan representasi visual tentang bagaimana data tersebut terdistribusi. Dengan KDE plot kita dapat memperkirakan distribusi data, misalnya apakah data terdistribusi secara normal, skewed, bimodal, dan lain sebagainya.

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data=gross_income, shade=True)
plt.axvline(x=np.mean(gross_income), color='blue', linestyle='--', label='Mean')
plt.axvline(x=np.median(gross_income), color='red', linestyle='--', label='Median')
plt.axvline(x=scp.mode(gross_income)[0], color='brown', linestyle='--', label='Mode')
plt.xlabel('Gross Income')
plt.ylabel('Density')
plt.title('Distribusi Gross Income Transaksi')
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# Dari visualisasi distribusi dengan KDE plot di atas, dapat dengan mudah dilihat bahwa distribusi fitur `gross income` bersifat **skewed to the right** atau **positively skewed** karena longer tail ada di bagian kanan. Hal ini sesuai dengan dugaan awal kita saat menganalisis descriptive statistics. Dengan demikian, **median** adalah measurement yang lebih baik untuk merepresentasikan central tendency pada fitur `gross income`.
#
# Dapat terlihat pula pada visualisasi data di atas bahwa mean, median, dan mode tidak sama, yang merupakan karakteristik umum dari distribusi skewed. Dalam kasus ini:
# - Mean (ditandai dengan garis biru) lebih besar dari median (ditandai dengan garis merah) dan mode (ditandai dengan garis coklat) yang mengindikasikan bahwa beberapa nilai yang besar menarik rata-rata ke arah kanan.
# - Median terletak di antara mean dan mode menjadi lebih representatif tentang central tendency dari data dalam kasus distribusi skewed ini.
#
# Pada distribusi yang skewed, median sering kali menjadi pengukuran yang lebih baik untuk menggambarkan central tendency karena tidak terpengaruh oleh nilai ekstrem (berbeda dengan mean yang sensitif terhadap outliers). Oleh karena itu, **median** memberikan pandangan yang lebih stabil terhadap data yang terdistribusi skewed.

# %% [markdown]
# Kita juga bisa melihat skewness dengan method `.skew()`.

# %%
# Melihat skewness dari fitur 'gross income'
print(gross_income.skew())
# Out:
# 0.8925698049581423

# %% [markdown]
# Untuk membandingkan distribusi data pada ketiga supermarket yang berbeda, salah satu pendekatan yang dapat kita gunakan adalah dengan visualisasi **overlapping KDE plot**. Misalnya, jika kita ingin membandingkan distribusi `gross income` pada transaksi-transaksi di ketiga supermarket, kita dapat menggunakan pendekatan overlapping KDE plot. Berikut merupakan contoh penerapannya:

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Overlapping KDE plot
branch_A = df[df['Branch'] == 'A']
branch_B = df[df['Branch'] == 'B']
branch_C = df[df['Branch'] == 'C']

plt.figure(figsize=(12,10))

# Plot ketiga KDE
sns.kdeplot(branch_A['gross income'], shade=True)
sns.kdeplot(branch_B['gross income'], shade=True)
sns.kdeplot(branch_C['gross income'], shade=True)

# Plot garis yang merepresentasikan mean
plt.axvline(x=branch_A['gross income'].mean(), color='blue', linestyle='--')
plt.axvline(x=branch_B['gross income'].mean(), color='orange', linestyle='--')
plt.axvline(x=branch_C['gross income'].mean(), color='green', linestyle='--')

# Legend
plt.legend(['Branch A', 'Branch B', 'Branch C', 'Branch A Gross Income Average', 'Branch B Gross Income Average', 'Branch C Gross Income Average'], fontsize=12)

plt.show()

# %% [markdown]
# ## Korelasi
#
# Korelasi dalam data science mengacu pada hubungan statistik antara dua atau lebih fitur. Dengan memanfaatkan korelasi, kita dapat memahami bagaimana perubahan pada satu fitur terkait dengan perubahan pada fitur lainnya. Korelasi mengukur sejauh mana dua fitur bergerak bersama-sama atau memiliki ketergantungan dalam pola tertentu.
#
# Ada dua jenis korelasi yang sering digunakan:
#
# - Korelasi positif: Ketika dua fitur memiliki korelasi positif, ini berarti ketika satu fitur meningkat, fitur lainnya juga cenderung meningkat, dan sebaliknya. Hal ini menunjukkan adanya hubungan searah antara kedua fitur tersebut.
#
# - Korelasi negatif: Jika dua fitur memiliki korelasi negatif, artinya ketika satu fitur naik, fitur lainnya cenderung turun, dan sebaliknya. Ini menunjukkan adanya hubungan terbalik antara kedua fitur.
#
# Korelasi dapat diukur menggunakan koefisien korelasi, dengan **koefisien korelasi Pearson** sebagai salah satu yang paling umum digunakan. Koefisien ini memiliki rentang nilai antara -1 hingga 1:
#
# - Nilai -1 menunjukkan korelasi negatif sempurna, artinya kedua fitur bergerak berlawanan arah secara linier.
# - Nilai antara -1 dan 0: menunjukkan korelasi negatif, kedua fitur cenderung bergerak berlawanan arah secara linier.
# - Nilai 0 menunjukkan tidak ada korelasi linier antara kedua fitur tersebut.
# - Nilai antara 0 dan 1: menunjukkan korelasi positif, kedua fitur cenderung bergerak searah secara linier.
# - Nilai +1 menunjukkan korelasi positif sempurna, artinya kedua fitur bergerak searah secara linier.
#
# Korelasi adalah alat penting dalam analisis data karena membantu kita mengidentifikasi hubungan antar fitur, memprediksi perilaku data atau fitur, dan membuat keputusan yang lebih baik berdasarkan pemahaman tentang bagaimana fitur-fitur tersebut saling berkaitan. Namun, perlu diingat bahwa korelasi hanya menunjukkan adanya hubungan atau pola antara fitur, bukan hubungan sebab-akibat atau kausalitas. Oleh karena itu, kehati-hatian sangat diperlukan dalam menginterpretasikan hasil korelasi.

# %%
# Seleksi hanya fitur numerik untuk perhitungan korelasi Pearson (kecuali gross margin percentage karena nilainya konstan)
numeric_df = df.select_dtypes(include=[np.number]).drop(columns=['gross margin percentage'])

# Implementasi korelasi Pearson hanya untuk fitur numerik
correlation_matrix = numeric_df.corr(method='pearson')
correlation_matrix
# Out:
#               Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price      1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity        0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%          0.633962  0.705510  1.000000  1.000000  1.000000
# Total           0.633962  0.705510  1.000000  1.000000  1.000000
# cogs            0.633962  0.705510  1.000000  1.000000  1.000000
# gross income    0.633962  0.705510  1.000000  1.000000  1.000000
# Rating         -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#               gross income    Rating
# Unit price        0.633962 -0.008778
# Quantity          0.705510 -0.015815
# Tax 5%            1.000000 -0.036442
# Total             1.000000 -0.036442
# cogs              1.000000 -0.036442
# gross income      1.000000 -0.036442
# Rating           -0.036442  1.000000

# %% [markdown]
# Berdasarkan correlation matrix di atas dapat dilihat bahwa:
# - `Tax 5%`, `Total`, `cogs`, dan `gross income` memiliki korelasi positif sempurna yanng mnunjukkan bahwa terdapat hubungan linier positif sempurna yang searah. Hal ini berarti semakin tinggi Tax 5%, berarti semakin tinggi juga Total, cogs, dan gross income, dan seterusnya. Silakan explore sendiri mengapa hal ini bisa terjadi :D
# - `Rating` hanya memiliki korelasi negatif yang sangat lemah dengan semua fitur lainnya yang berarti semakin tinggi Rating, ada kecenderungan kecil bahwa semakin rendah juga Unit price, Quantity, Tax 5%, Total, cogs, dan gross income
# - `cogs` dan `Quantity` memiliki korelasi positif yang kuat (0.71) yang berarti semakin tinggi kuantitas produk yang dibeli, cogs atau total harga (sebelum tax) juga cenderung semakin mahal. Hal ini masuk akal karena semakin banyak produk yang dibeli berarti pengali unit price-nya jadi semakin banyak juga.
# - Dan seterusnya :D

# %% [markdown]
# Selain metode pearson, ada metode korelasi lain yang pernah dipelajari di mata kuliah Statistika dan Probabilitas, yaitu metode spearman rho. Perbedaan mendasar antara kedua metode tersebut adalah bahwa metode pearson dihitung berdasarkan perbedaan antara nilai sebenarnya dan rata-rata, kemudian dibagi dengan standar deviasi, sedangkan metode spearman rho dihitung berdasarkan peringkat (peringkat ordinal) dari nilai setiap fitur karena penghitungan dengan pearson menggunakan rata-rata dan varians, skala pengukuran fitur harus dipastikan dalam bentuk interval dan rasio. Sebaliknya, penghitungan spearman rho menggunakan peringkat, sehingga metode ini juga dapat mengukur korelasi untuk fitur dengan skala pengukuran ordinal.

# %%
correlation_matrix = numeric_df.corr(method='spearman')
correlation_matrix
# Out:
#               Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price      1.000000  0.011167  0.630054  0.630054  0.630054
# Quantity        0.011167  1.000000  0.735265  0.735265  0.735265
# Tax 5%          0.630054  0.735265  1.000000  1.000000  1.000000
# Total           0.630054  0.735265  1.000000  1.000000  1.000000
# cogs            0.630054  0.735265  1.000000  1.000000  1.000000
# gross income    0.630054  0.735265  1.000000  1.000000  1.000000
# Rating         -0.008335 -0.015453 -0.017226 -0.017226 -0.017226
#
#               gross income    Rating
# Unit price        0.630054 -0.008335
# Quantity          0.735265 -0.015453
# Tax 5%            1.000000 -0.017226
# Total             1.000000 -0.017226
# cogs              1.000000 -0.017226
# gross income      1.000000 -0.017226
# Rating           -0.017226  1.000000

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Scatter Plot untuk Melihat Korelasi dan Keterhubungan 2 Fitur

# %%
# Scatterplot Unit price vs gross income
df_subset = df[["Unit price", "gross income"]]
plt.figure(figsize=(8, 6))
plt.scatter(df_subset["Unit price"], df_subset["gross income"], alpha=0.5, label="Data Points")

# Perhitungan linear regression
w = df_subset["Unit price"]
z = df_subset["gross income"]
m, b = np.polyfit(w, z, 1)  # m = slope, b = intercept

# Plot regression line
plt.plot(w, m * w + b, color='red', label=f"Regression Line (y={m:.2f}x + {b:.2f})")
plt.xlabel("Unit Price")
plt.ylabel("Gross Income")
plt.title("Unit Price VS Gross Income")
plt.legend()
plt.show()

# %% [markdown]
# - Alasan penggunaan scatter plot adalah dapat menunjukkan apakah terdapat hubungan linier antara kedua fitur. Selain itu, jika memang ada hubungan linier, kita juga dapat dengan mudah melihat arahnya (apakah searah atau berlawanan arah). Jika garis regresi ke arah kanan atas berarti hubungan liniernya searah. Sebaliknya, jika garis regresi ke arah kanan bawah berarti hubungan liniernya berlawanan arah.
# - Visualisasi di atas menunjukkan adanya hubungan positif yang signifikan antara `Unit price` dan `gross income`, di mana peningkatan harga per unit produk cenderung berkorelasi dengan peningkatan gross income yang terkait dengan transaksi produk tersebut. Garis regresi linier yang dihasilkan, dengan persamaan $y = 0.28x - 0.22$ mengindikasikan bahwa untuk setiap kenaikan satu unit dalam unit price, gross income meningkat sekitar 0.28 unit. Meskipun tren linier ini tampak cukup kuat, terdapat persebaran yang cukup lebar pada transaksi yang melibatkan produk dengan unit price produk yang lebih mahal, menunjukkan bahwa meskipun unit price produk merupakan prediktor penting untuk gross income, faktor lain mungkin juga berkontribusi terhadap variasi ini. Analisis lebih lanjut diperlukan untuk memahami variasi dalam gross income yang tidak sepenuhnya dijelaskan oleh unit price.

# %% [markdown]
# ### Bar Chart untuk Melihat Rata-Rata Total Penjualan di Setiap Branch Supermarket

# %%
# Menghitung rata-rata Total price di setiap transaksi pada masing-masing branch
average_total = df.groupby('Branch')['Total'].mean().reset_index()

plt.figure(figsize=(15, 6))
sorted_data = average_total.sort_values('Total', ascending=False)
ax = sns.barplot(y='Branch', x='Total', data=sorted_data, palette='viridis')
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
plt.title("Rata-Rata Total Price di Setiap Branch")
plt.xlabel("Total")
plt.ylabel("Branch")
plt.show()

# %% [markdown]
# - Alasan penggunaan horizontal bar chart adalah karena fitur `Branch` yang sifatnya nominal, apabila digunakan versi vertikal bisa jadi menyebabkan bias saat interpretasi
# - Visualisasi di atas mempermudah kita untuk melihat branch mana yang memiliki rata-rata total penjualan tertinggi, terkecil, melihat urutannya, dan lainnya.
# - Berdasarkan visualisasi di atas, kita tahu bahwa branch C memiliki rata-rata total penjualan tertinggi (337.10), kemudian dilanjut dengan branch B (319.87), dan terakhir branch A (312.35).
# - Untuk bisa mencari tahu penyebab hal ini, kita bisa eksplor lebih lanjut dan mengaitkannya dengan fitur-fitur lain, misalnya dengan Product line apa yang paling populer di masing-masing branch, dan lainnya.

# %% [markdown]
# ### Multiple Count Bar Chart untuk Melihat Distribusi Jumlah Pelanggan berdasarkan `Payment` (Metode Pembayaran) dan `Customer type` (Member VS Non-Member)

# %%
plt.figure(figsize=(12, 6))

# Count bar plot
ax = sns.countplot(y='Payment', hue='Customer type', data=df, palette='viridis')

# Memberikan label pada setiap bar
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

plt.title("Distribusi Jumlah Pelanggan berdasarkan Payment Method dan Customer type")
plt.xlabel("Payment Method")
plt.ylabel("Customer Type")
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Alasan penggunaan horizontal multiple bar chart adalah karena fitur `Payment` yang sifatnya nominal, apabila digunakan versi vertikal bisa jadi menyebabkan bias saat interpretasi. Selain itu, kita perlu melihat untuk kedua tipe pelanggan (member/non-member), jadi kita perlu multiple bar.
# - Visualisasi di atas mempermudah kita untuk melihat setiap metode pembayaran lebih sering digunakan oleh kelompok pelanggan yang mana (member atau non-member). Selain itu, kita bisa lihat juga masing-masing kelompok pelanggan paling banyak menggunakan metode pembayaran apa
# - Berdasarkan visualisasi di atas, dapat dengan mudah kita simpulkan bahwa metode pembayaran yang paling banyak digunakan oleh pelanggan non-member adalah Ewallet (184) dan metode pembayaran yang paling banyak digunakan oleh pelanggan member adalah Credit card (172). Selain itu, kita bisa lihat juga yang plaing sedikit, dan seterusnya.

# %% [markdown]
# ### Pie Chart untuk Melihat Distribusi Proporsi Pelanggan berdasarkan `Customer Type` (Member VS Non-Member)

# %%
# Pie Chart untuk meilihat distribusi proporsi
customer_counts = df['Customer type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(customer_counts,labels=customer_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set2'), startangle=120)
plt.title("Distribusi Proporsi setiap Customer Type")
plt.show()

# %% [markdown]
# - Alasan penggunaan pie chart adalah karena dapat menampilkan distribusi proporsi dengan sangat baik jika banyaknya unique value masih cukup sedikit. Selain itu, pie chart juga mudah untuk diinterpretasikan.
# - Dari visualisasi di atas, kita bisa melihat bahwa proporsi pelanggan yang merupakan member adalah 50.1%. Nilai ini hampir sama dengan pelanggan yang bukan member yaitu 49.9%. Jadi, banyaknya pelanggan yang merupakan member dan bukan member dapat dikatakan hampir sama, hanya selisih 0.2% dari total 1000 pengguna.

# %% [markdown]
# ### Box Plot untuk Melihat Distribusi Total Price Transaksi berdasarkan Kota Supermarket

# %%
# Box plot untuk melihat distribusi
plt.figure(figsize=(10, 6))
sns.boxplot(x='Total', y='Branch', data=df, palette='Set2')
plt.title('Distribusi Total Price Transaksi berdasarkan Branch Supermarket')
plt.xlabel('Total')
plt.ylabel('Branch')
plt.show()

# %% [markdown]
# - Alasan penggunaan box plot adalah karena dapat memberikan gambaran tentang distribusi data yang mencakup median, quartile, IQR, range, dan outliers. Selain itu, box plot juga cocok untuk membandingkan distribusi beberapa kelompok data secara visual dalam satu plot
# - Insights yang diperoleh:
#     - Distribusi total price di ketiga branch terindikasi skewed to the right atau positively skewed karena terlihat lebih padat di bagian kiri box plot yang berarti mayoritas transaksi memiiliki total price yang cenderung kecil
#     - Terdapat outliers (nilai extreme) pada branch A dan B karena melebihi RUB
#     - Persebaran total price yang paling bervariasi ada di branch C karena memiliki IQR yang terbesar (box paling lebar) dan memiliki RUB yang paling besar yang berarti transaksi-transaksi di branch C memiliki total price yang paling bervariasi

# %% [markdown]
# # Latihan Soal Bagian A: Descriptive Statistics, Central Tendency, Correlation

# %% [markdown]
# Silakan tambahkan code/text cell jika perlu.

# %% [markdown]
# #### [10 poin] 1. Tampilkan descriptive statistics fitur `Total` dari transaksi `Product line` berjenis **Fashion accessories**, yaitu mean, median, mode, standar deviasi, variance, minimum value, maximum value, range, Q1, Q2, Q3, IQR, Percentile-10, dan Percentile-90. Setelah itu, berikan analisis singkat dari statisics yang Anda dapatkan.

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %%
# Jawaban 1

# pertama membuat df baru, agar hanya transaksi product line fashion accessories saja 
df_FA = df[df['Product line'] == 'Fashion accessories' ]

df_FA.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender         Product line  \
# 10  351-62-0822      B   Mandalay        Member  Female  Fashion accessories
# 26  649-29-6775      B   Mandalay        Normal    Male  Fashion accessories
# 27  189-17-4241      A     Yangon        Normal  Female  Fashion accessories
# 30  871-79-8483      B   Mandalay        Normal    Male  Fashion accessories
# 49  574-22-5561      C  Naypyitaw        Member  Female  Fashion accessories
#
#     Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 10       14.48         4   2.8960   60.8160   2/6/2019  18:07      Ewallet
# 26       33.52         1   1.6760   35.1960   2/8/2019  15:31         Cash
# 27       87.67         2   8.7670  184.1070  3/10/2019  12:17  Credit card
# 30       94.13         5  23.5325  494.1825  2/25/2019  19:39  Credit card
# 49       82.63        10  41.3150  867.6150  3/19/2019  17:08      Ewallet
#
# ...

# %%
# kemudian karena diminta descriptive statistic fitur total, kita mengambil fitur total
total_arr = df_FA['Total']

total_arr
# Out:
# 10      60.8160
# 26      35.1960
# 27     184.1070
# 30     494.1825
# 49     867.6150
#          ...
# 974    180.8730
# 975    104.8320
# 985    334.4775
# 993    183.6450
# 999    649.2990
# Name: Total, Length: 178, dtype: float64

# %%
# referensi : tutorial kasdad lab 2 
# menghitung statistik deskriptif berdasarkan metric yang diminta, memanfaatkan library numpy untuk perhitungan
stats = [
    ['Mean', np.mean(total_arr)],
    ['Median', np.median(total_arr)],
    ['Mode', scp.mode(total_arr)[0]],
    ['Standard Deviation', np.std(total_arr)],
    ['Variance', np.var(total_arr)],
    ['Minimum', np.min(total_arr)],
    ['Maximum', np.max(total_arr)],
    ['Range', np.ptp(total_arr)],  
    ['Q1', np.quantile(total_arr, 0.25)],
    ['Q2 (Median)', np.quantile(total_arr, 0.5)],
    ['Q3', np.quantile(total_arr, 0.75)],
    ['IQR', np.quantile(total_arr, 0.75) - np.quantile(total_arr, 0.25)],
    ['Percentile 10', np.percentile(total_arr, 10)],
    ['Percentile 90', np.percentile(total_arr, 90)]
]

pd.DataFrame(stats, columns=['Measure', 'Value'])
# Out:
#                Measure         Value
# 0                 Mean    305.089298
# 1               Median    211.648500
# 2                 Mode     93.744000
# 3   Standard Deviation    242.878997
# 4             Variance  58990.207264
# 5              Minimum     12.694500
# 6              Maximum   1042.650000
# 7                Range   1029.955500
# 8                   Q1    106.155000
# 9          Q2 (Median)    211.648500
# 10                  Q3    442.690500
# 11                 IQR    336.535500
# 12       Percentile 10     54.008850
# 13       Percentile 90    662.497500

# %% [markdown]
# Jawaban 1
#
# Dari hasil deskriptif statistik diatas, kita dapat menentukan measurement central tendency terbesar dimiliki oleh **mean** dengan urutan mean > median > mode. Oleh karena itu distribusi data kemungkinan **skewed to the right** atau **positively skewed** (condong ke kanan).
#
# Kemudian standar deviasi bernilai 242.878997 dan variance yang juga konsisten tinggi bernilai 58,990.21. Hal ini menunjukkan variasi nilai transaksi sangat besar dan penyebaran nilai transaksi cukup luas. Selain itu Range bernilai 1,029.96 menunjukkan transaksi sangat bervariasi, dari transaksi kecil (12.69) hingga yang sangat besar (1,042.65).
#
# Dari analisis kuartil, didapat nilai Q1 (106.155), Q2 (211.648500), Q3 (442.690500), dan IQR (336.5355). Disimpulkan transaksi dalam kelompok menengah-paling atas cukup bervariasi.
#
# Lalu dari hasil percentile, didapat nilai Percentile 10 adalah 54.00 (10% transaksi memiliki total ≤ 54.00 ). Percentile 90 adalah (662.50 → 90% transaksi memiliki total ≤ 662.50). Perbedaan besar antara P10 dan P90 kemungkinan menunjukkan adanya outlier (transaksi ekstrem) di bagian atas distribusi.
#
# Untuk melihat outlier/ informasi lain mungkin perlu analisa lebih lanjut.

# %% [markdown]
# #### [10 poin] 2. Apa measurement central tendency yang paling cocok digunakan untuk mendeskripsikan fitur `Rating`? Berikan visualisasi serta justifikasi yang dapat mendukung jawaban Anda.

# %% [markdown]
# **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %%
# Jawaban 2
# melihat sekilas measurement central tendency

# melihat mean
print(df['Rating'].mean())
# Out:
# 6.9727

# %%
# melihat median
print(df['Rating'].median())
# Out:
# 7.0

# %%
# melihat mode
df['Rating'].mode()
# Out:
# 0    6.0
# Name: Rating, dtype: float64

# %%
# membuat array rating untuk visualisasi
rating_arr = df['Rating']
rating_arr
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
# visualisasi 
# referensi : lab tutorial kasdad 2
plt.figure(figsize=(10, 5))
sns.kdeplot(data=rating_arr, shade=True, color="skyblue")
plt.axvline(x=np.mean(rating_arr), color='blue', linestyle='--', label=f'Mean: {np.mean(rating_arr):.2f}')
plt.axvline(x=np.median(rating_arr), color='red', linestyle='--', label=f'Median: {np.median(rating_arr):.2f}')
plt.axvline(x=scp.mode(rating_arr)[0], color='brown', linestyle='--', label=f'Mode: {scp.mode(rating_arr)[0]:.2f}')
plt.xlabel('Rating')
plt.ylabel('Density')
plt.title('Distribusi Rating')
plt.legend(fontsize=12)
plt.show()

# %%
# visualisasi boxplot untuk melihat outlier 
# referensi :lab tutorial kasdad 2,  https://accounting.binus.ac.id/2020/12/19/mengenal-box-plot-box-and-whisker-plots/

plt.figure(figsize=(10, 5))
# whis diatur ke 1.5 untuk mengidentifikasi outlier
sns.boxplot(data=rating_arr, color="skyblue", whis=1.5, width=0.7)
plt.title("Boxplot Rating dengan Outliers")
plt.xlabel("Rating")
plt.ylabel("Nilai")
plt.show()

# %% [markdown]
# Jawaban 2
#
# Dari hasil visualisasi diatas, didapat distribusi data yang cenderung simetris (ditunjukkan dari nilai mean dan median yang sangat berdekatan dengan selisih hanya 0.0273) serta tidak adanya outlier yang dapat mempengaruhi nilai mean (ditunjukkan dari hasil boxplot).
#
# Untuk measurement central tendency baik mean (6.9727) maupun median (7.0) dapat digunakan untuk merepresentasikan fitur Rating. Namun saya lebih merekomendasikan  penggunaan **mean**
#
# Hal ini karena mean memberikan informasi yang lebih detail dengan empat angka desimal (6.9727) dibandingkan median (7.0), sehingga lebih tepat untuk menggambarkan perbedaan dalam rating yang bersifat kontinu. Namun, jika diperlukan komunikasi yang lebih sederhana,  median (7.0) juga dapat menjadi pilihan yang valid karena nilainya yang bulat dan intuitif, serta tetap merepresentasikan nilai tengah yang akurat dari distribusi rating.

# %% [markdown]
# #### [10 poin] 3. Buatlah heat map 4x4 dengan korelasi Pearson untuk melihat keterhubungan antara fitur `Unit price`, `Quantity`, `Total`, dan `Rating`. Setelah itu, berikan analisis dan insight yang Anda peroleh terkait keterhubungan keempat fitur tersebut.

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %%
# Jawaban 3

# memilih fitur untuk korelasi
features = ['Unit price', 'Quantity', 'Total', 'Rating']

# memastikan semua kolom numerik karena menggunakan pearson
df[features].dtypes
# Out:
# Unit price    float64
# Quantity        int64
# Total         float64
# Rating        float64
# dtype: object

# %%
# mencari korelasi antar fitur
# menghitung korelasi antar fitur
df1c = df[features].corr(method='pearson')
df1c
# Out:
#             Unit price  Quantity     Total    Rating
# Unit price    1.000000  0.010778  0.633962 -0.008778
# Quantity      0.010778  1.000000  0.705510 -0.015815
# Total         0.633962  0.705510  1.000000 -0.036442
# Rating       -0.008778 -0.015815 -0.036442  1.000000

# %%
# membuat visualisasi
# referensi : lab kasdad tahun lalu (2023/2024) , https://drive.google.com/drive/folders/19SnfT6yl-X33y05ZnnUPSckdzA6wfOgp?usp=sharing 
plt.figure(figsize=(10, 5))
sns.heatmap(df1c, annot = True, cmap='coolwarm', linewidths=0.5)
plt.title("Heatmap Korelasi Pearson antara Unit Price, Quantity, Total, dan Rating")
plt.show();

# %% [markdown]
# Jawaban 3
#
# Dari hasil ditemukan bahwa Total memiliki korelasi kuat dengan Quantity (0.71) dan Unit Price (0.63).Dengan kata lain, semakin tinggi harga produk atau semakin banyak unit yang dibeli, semakin tinggi pula total pembelian. Hal ini masuk akal karena bila dilihat dari deskripsi dataset, Total: Total price including tax. Secara intuitif disimpulkan total pembelian merupakan hasil perkalian dari harga satuan dengan kuantitas.
#
# Selanjutnya korelasi antara Unit Price dan Quantity sangat lemah (0.011), yang mengindikasikan bahwa harga produk tidak mempengaruhi jumlah unit yang dibeli secara signifikan. Dimana pembeli mungkin membeli bukan semata karena harga melainkan karena kebutuhan.
#
# Kemudian bila dilihat rating memiliki korelasi negatif yang sangat lemah dengan ketiga kolom lain, Unit Price (-0.008), Quantity (-0.016), dan Total (-0.036). Hal ini bisa diartikan bahwa penilaian pelanggan terhadap produk atau layanan tidak banyak dipengaruhi oleh harga atau jumlah pembelian, melainkan faktor lain seperti customer service, kualitas produk, dll

# %% [markdown]
# # Latihan Soal Bagian B: Data Visualization and Analysis

# %% [markdown]
# #### **PETUNJUK PENTING:**
#
# > Untuk setiap soal pada bagian B, **pilih salah satu dari visualisasi di bawah ini dan jawab pertanyaan yang diberikan.**
#
# - Pie chart
# - Bar chart (perhatikan juga pemilihan bar chart versi horizontal/vertikal)
# - Histogram
# - Scatter plot
# - Box plot
# - KDE plot
# - Bubble plot
#
# > **Secara eksplisit, tuliskan chart apa yang Anda pilih disertai dengan alasannya** karena akan menjadi **bagian dari komponen penilaian setiap soal**.
# Beberapa kasus terkadang memiliki lebih dari satu "jawaban yang tepat" karena ada banyak cara untuk visualisasi data. Pilihlah yang menurut Anda paling cocok berdasarkan kasus yang diberikan.

# %% [markdown]
# #### [10 poin] 1. Visualisasikan keterkaitan antara fitur `cogs` (cost of goods sold) dengan fitur `Total` (harga total suatu transaksi). Apakah ada hubungan linier antara kedua fitur dan mengapa demikian?

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
# Untuk menganalisis keterkaitan antara cogs dan Total , saya memilih scatter plot.Hal ini karena jenis ini umum digunakan untuk melihat hubungan linier antara dua variabel numerik dan membantu mengidentifikasi pola atau tren dalam data.

# %%
# Jawaban 1
# referensi : tutorial lab 2 kasdad

# membuat scatterplot
df_subset = df[["cogs", "Total"]]
plt.figure(figsize=(8, 6))
plt.scatter(df_subset["cogs"], df_subset["Total"], alpha=0.5, label="Data Points", color="blue")

# Perhitungan linear regression
x = df_subset["cogs"]
y = df_subset["Total"]
m, b = np.polyfit(x, y, 1)  # m = slope, b = intercept

# Plot regression line
plt.plot(x, m * x + b, color='red', label=f"Regression Line (y = {m:.2f}x + {b:.2f})")
plt.xlabel("Cost of Goods Sold (COGS)")
plt.ylabel("Total Transaction Value")
plt.title("Scatter Plot: COGS vs Total")
plt.legend()
plt.show()

# %%
# karena hasil menunjukkan hubungan positif sempurna, maka saya mengecek korelasi untuk memastikan
df[["cogs", "Total"]].corr()
# Out:
#        cogs  Total
# cogs    1.0    1.0
# Total   1.0    1.0

# %% [markdown]
# Jawaban 1
#
# Dari hasil visualisasi, mereka menunjukkan hubungan linier positif sempurna antara cogs (cost of goods sold) dan Total
#
# dari deskripsi dataset didapat :
# - `Total`: Total price including tax
# - `cogs`: Cost of goods sold (before tax)
#
#
# Secara intuitif/umum Total dihitung langsung dari cogs dengan formula tetap:
#
# Total=cogs+(5%×cogs)
#
# Hal ini dapat menjelaskan hasil, karena Total selalu merupakan kelipatan tetap dari cogs, maka setiap perubahan di cogs akan selalu menghasilkan perubahan proporsional yang sama di Total. Oleh karena itu hubungan mereka linear positif

# %% [markdown]
# #### [10 poin] 2. Visualisasikan banyaknya setiap kategori `Product line` yang terlibat transaksi di setiap `City`. Product line apa yang paling populer di masing-masing kota? (**Hint:** populer di sini berarti paling banyak terlibat transaksi, bukan yang paling banyak dibeli dalam konteks kuantitas)

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Pada kasus ini saya memilih countplot ,walau ada pilihan lain tapi saya memilih countplot karena lebih sederhana dan langsung menghitung frekuensi tanpa perlu melakukan grouping(groupby) terlebih dahulu. Selain itu countplot memang didesain khusus untuk menghitung dan memvisualisasikan frekuensi. Lalu penggunaan countplot juga memudahkan perbandingan jumlah transaksi antar kategori dan antar kota

# %%
# Jawaban 2
# referensi : tutorial lab 2 kasdad
# visualisasi
plt.figure(figsize=(15, 8))
ax = sns.countplot(y='Product line', hue='City', data=df, palette='viridis')

for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

plt.title('Distribusi Product Line di Setiap City')
plt.xlabel('Jumlah Transaksi')
plt.ylabel('Product Line')
plt.legend(title='City', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Jawaban 2
#
# Dari hasil diatas didapat product line yang populer untuk masing-masing kota adalah :
# - Mandalay : fashion accesories serta sports and travel (62 transaksi)
# - Naypyithaw : foods and beverage (66 transaksi)
# - Yangon : Home and lifestyle (65 transaksi)

# %% [markdown]
# #### [10 poin] 3. Visualisasikan proporsi metode pembayaran yang digunakan pada transaksi-transaksi yang dilakukan oleh pelanggan yang **bukan** member. Metode pembayaran apa yang paling banyak dan paling sedikit digunakan oleh pelanggan yang **bukan** member?

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Untuk kasus ini saya memilih menggunakan pie chart, hal ini karena saya ingin menampilkan proporsi/komposisi dari kategori (metode pembayaran). Lalu juga bila dilihat kategorinya sedikit (hanya 3 metode pembayaran) dengan data nominal. Sehingga cocok jika kita ingin melihat perbandingan bagian terhadap keseluruhan

# %%
# filter berdasarkan customer type
# dari deskripsi dataset :
# `Customer type`: Type of customers, recorded by Members for customers using member card and Normal for without member card.
non_member_df = df[df['Customer type'] == 'Normal']
non_member_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715      A     Yangon        Normal    Male
# 993  690-01-6631      B   Mandalay        Normal    Male
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 998  347-56-2442      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# ...

# %%
# menghitung jumlah sebaran payment untuk non member
payment_counts = non_member_df['Payment'].value_counts()
payment_counts
# Out:
# Payment
# Ewallet        184
# Cash           176
# Credit card    139
# Name: count, dtype: int64

# %%
# referensi : tutorial lab 2 kasdad
# visualisasi
plt.figure(figsize=(8, 8))
plt.pie(payment_counts, 
        labels=payment_counts.index, 
        autopct='%1.1f%%', 
        colors=sns.color_palette('Set2'), 
        startangle=120)
plt.title("Distribusi Metode Pembayaran untuk Pelanggan Non-Member")
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi, dapat dilihat bahwa E-wallet merupakan metode pembayaran yang paling banyak digunakan dengan proporsi 36,9% dari total transaksi, diikuti oleh Cash dengan proporsi yang hampir sama yaitu 35,3%. Sementara itu, Credit card menjadi metode pembayaran yang paling sedikit digunakan dengan proporsi 27,9% dari total transaksi pelanggan non-member.
#
# Selain itu perbedaan proporsi antara ketiga metode pembayaran ini tidak terlalu signifikan (rentang sekitar 9%), yang menunjukkan bahwa pelanggan non-member cukup seimbang dalam memilih metode pembayaran mereka.

# %% [markdown]
# #### [10 poin] 4. Visualisasikan distribusi `gross income` untuk setiap kategori `Product line`. Apakah terdapat transaksi product line yang menghasilkan gross income secara signifikan lebih banyak atau lebih sedikit dibandingkan dengan mayoritas transaksi pada product line tersebut? Jika iya, product line apa saja dan mengapa demikian? Jika tidak, mengapa demikian?

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Pada kasus ini saya memilih box plot karena dapat memperlihatkan median, kuartil, dan sebaran data. Selain itu objektif utama yaitu outlier (data ekstrem) dapat langsung terlihat, membantu mengidentifikasi transaksi yang menghasilkan gross income sangat tinggi atau rendah.
# Selain itu, boxplot juga memudahkan perbandingan antar kategori Product line.

# %%
# Jawaban 4

# referensi : tutorial lab 2 kasdad, https://stackoverflow.com/questions/6705581/rotating-xticks-causes-the-ticks-to-be-partially-hidden
plt.figure(figsize=(10, 6))
sns.boxplot(x="Product line", y="gross income", data=df, palette="Set2")
plt.xticks(rotation=30)
plt.xlabel("Product Line")
plt.ylabel("Gross Income")
plt.title("Distribusi Gross Income untuk Setiap Product Line");

# %% [markdown]
# Jawaban 4
#
# Secara signifikan lebih banyak atau lebih sedikit dibandingkan dengan mayoritas transaksi -> outlier
#
# Dari visualisasi terdapat beberapa outlier seperti pada sports and travel, food and beverages, dan fashion accesories
#
# Secara umum outlier dapat disebabkan oleh kesalahan entri data, pengambilan sampel data yang salah, nilai yang diskalakan secara tidak tepat, atau sekadar pengamatan yang sah tetapi tidak biasa,
#
# referensi :  https://www.atlantbh.com › outliers-in-data-and-how-to...
#
# Namun bila dilihat dari jenis datanya (gross income), penyebab adanya outlier ini bisa disebabkan oleh beberapa faktor seperti pembelian dalam jumlah besar (bulk purchase), transaksi produk premium dengan margin tinggi, dll.

# %% [markdown]
# #### [10 poin] 5. Visualisasikan rata-rata `gross income` untuk masing-masing kategori `Product line`. Product line apakah yang secara rata-rata memberikan gross income tertinggi dan terendah? Apakah terdapat perbedaan yang menonjol antara rata-rata gross income masing-masing product line?

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Visualisasi yang cocok untuk kasus ini adalah horizontal bar chart. Saya memilih visualisasi ini karena Bar chart memudahkan kita melihat perbedaan rata-rata gross income antar kategori dengan panjang batang sebagai indikator nilai. Lalu saya memilih dalam bentuk horizontal karena kategori Product line memiliki nama yang panjang, bar chart horizontal lebih mudah dibaca dibandingkan vertikal. Selain itu karena Product line memiliki jumlah kategori yang tidak banyak, bar chart cocok digunakan untuk membandingkan nilai rata-rata.

# %%
# Jawaban 5
# referensi : tutorial lab 2 kasdad
average_gross = df.groupby('Product line')['gross income'].mean().reset_index()
plt.figure(figsize=(15, 6))
sorted_data = average_gross.sort_values('gross income', ascending=False)
ax = sns.barplot(y='Product line', x='gross income', data=sorted_data, palette='viridis')
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', label_type='edge', padding=3)
plt.title("Rata-Rata Gross Income di Setiap Product Line")
plt.xlabel("Gross Income")
plt.ylabel("Product Line")
plt.show()

# %% [markdown]
# Jawaban 5
#
# Dari hasil dapat kita lihat urutan dari tertinggi-terendah, dengan rata-rata gross income tertinggi adalah Home and lifestyle dengan 16.03, sedangkan yang terendah adalah Fashion accessories dengan 14.53. Lalu dapat dilihat juga perbedaan antar product line, dimana tidak terlihat perbedaan yang terlalu menonjol.
#
# Hal ini karena rentang nilai (range) gross income kecil, hanya berkisar antara 14.53 hingga 16.03 (selisih sekitar 1.5 poin). Bila kita lihat juga penurunan nilai antar product line cenderung gradual:
#
# - Home and lifestyle (16.03)
# - Sports and travel (15.81) - turun 0.22
# - Health and beauty (15.41) - turun 0.40
# - dst

# %% [markdown]
# #### [10 poin] 6. Visualisasikan proporsi `Product line` pada transaksi-transaksi di `City` Naypyitaw. Jenis product line apa yang paling populer dan paling tidak populer di Kota Naypyitaw? (**Hint:** populer di sini berarti paling banyak terlibat transaksi, bukan yang paling banyak dibeli dalam konteks kuantitas).

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Saya memilih pie chart karena data yang divisualisasikan adalah data kategorikal (Product line), juga karena kita ingin melihat proporsi/komposisi dari keseluruhan. Pie chart juga dapat dengan cepat mengidentifikasi kategori yang paling dominan dan paling sedikit. Selain itu, bila dilihat jumlah kategori Product line juga tidak terlalu banyak (6 kategori) sehingga masih ideal untuk pie chart

# %%
# Jawaban 6
# referensi : tutorial lab 2 kasdad
# memfilter df agar hanya city naypyitaw
product_counts = df[df['City'] == 'Naypyitaw']['Product line'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(product_counts, 
        labels=product_counts.index, 
        autopct='%1.1f%%', 
        colors=sns.color_palette('Set2'), 
        startangle=120)

plt.title("Distribusi Proporsi Product Line di Naypyitaw")
plt.show()

# %% [markdown]
# Jawaban 6
#
# berdasarkan hasil, didapat bahwa Product line yang paling populer adalah Food and beverages dengan proporsi 20,1% dari total transaksi di Naypyitaw.
#
# Sedangkan Product line yang paling tidak populer  adalah Sports and travel dan Home and lifestyle yang sama-sama memiliki proporsi 13,7% dari total transaksi di Naypyitaw.

# %% [markdown]
# #### [10 poin] 7. Visualisasikan keterhubungan antara fitur `Unit price`, `Quantity`, dan `gross income`. Setelah itu, jelaskan insight yang Anda peroleh terkait keterhubungan antara ketiga fitur tersebut.

# %% [markdown]
# > **Jika ada**, Anda wajib mencantumkan semua sumber yang menjadi referensi jawaban Anda (termasuk Chatbot).

# %% [markdown]
# #### Alasan visualisasi
#
# Pada kasus ini saya memilih bubble plot, hal ini karena bubble plot efektif untuk menunjukkan hubungan/korelasi antara variabel numerik. Selain itu karena ada tiga variable, kita bisa memanfaatkan ukuran titik/warna (bubble plot) untuk merepresentasikan variabel ketiga (gross income) .

# %%
# Jawaban 7

# referensi : chatgpt
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    df["Unit price"], df["Quantity"], 
    s=df["gross income"] * 10,  # Ukuran bubble berdasarkan gross income (dikali untuk visibilitas)
    alpha=0.5, 
    c=df["gross income"], cmap="viridis", edgecolors="black"
)

plt.colorbar(label="Gross Income")
plt.xlabel("Unit Price ($)")
plt.ylabel("Quantity")
plt.title("Hubungan Unit Price, Quantity, dan Gross Income")
plt.show()

# %%
# melihat korelasi agar lebih pasti
features = ['Unit price', 'Quantity', 'gross income']

# hitung correlation matrix
df[features].corr()
# Out:
#               Unit price  Quantity  gross income
# Unit price      1.000000  0.010778      0.633962
# Quantity        0.010778  1.000000      0.705510
# gross income    0.633962  0.705510      1.000000

# %% [markdown]
# Jawaban 7
#
# Dari visualisasi bubble plot, terlihat bahwa produk dengan Unit Price tinggi cenderung menghasilkan Gross Income yang lebih besar, terutama ketika Quantity juga tinggi. Lalu titik dengan warna lebih terang (ujung kanan) menunjukkan bahwa kombinasi harga tinggi dan jumlah pembelian tinggi memberikan pendapatan tertinggi. Sebaliknya, produk dengan harga lebih rendah dengan jumlah kecil tidak menghasilkan pendapatan yang cukup baik.
